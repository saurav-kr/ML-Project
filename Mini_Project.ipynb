# %% [markdown]
# <a href="https://colab.research.google.com/github/saurav-kr/ML-Project/blob/master/Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df= pd.read_csv('Admission_Predict.csv')
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0             1        337          118  ...  9.65         1              0.92
# 1             2        324          107  ...  8.87         1              0.76
# 2             3        316          104  ...  8.00         1              0.72
# 3             4        322          110  ...  8.67         1              0.80
# 4             5        314          103  ...  8.21         0              0.65
# ..          ...        ...          ...  ...   ...       ...               ...
# 395         396        324          110  ...  9.04         1              0.82
# 396         397        325          107  ...  9.11         1              0.84
# 397         398        330          116  ...  9.45         1              0.91
# 398         399        312          103  ...  8.78         0              0.67
# 399         400        333          117  ...  9.66         1              0.95
#
# [400 rows x 9 columns]

# %%
df = df.drop(columns=['Serial No.'])
df
# Out:
#      GRE Score  TOEFL Score  ...  Research  Chance of Admit
# 0          337          118  ...         1              0.92
# 1          324          107  ...         1              0.76
# 2          316          104  ...         1              0.72
# 3          322          110  ...         1              0.80
# 4          314          103  ...         0              0.65
# ..         ...          ...  ...       ...               ...
# 395        324          110  ...         1              0.82
# 396        325          107  ...         1              0.84
# 397        330          116  ...         1              0.91
# 398        312          103  ...         0              0.67
# 399        333          117  ...         1              0.95
#
# [400 rows x 8 columns]

# %%
# %matplotlib inline
sns.pairplot(df,x_vars=['GRE Score','TOEFL Score','University Rating','SOP','LOR ','CGPA','Research'],y_vars=['Chance of Admit '],size=7, aspect=0.7, kind='reg')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
x=df.iloc[:,0:7].values
y=df.iloc[:,7].values

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state = 1)

# %%
x_train.shape
# Out:
# (280, 7)

# %%
x_test.shape
# Out:
# (120, 7)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
y_pred
# Out:
# array([0.72166114, 0.69304191, 0.79027464, 0.78449776, 0.85244983,
#        0.64480654, 0.63786861, 0.55308445, 0.49774164, 0.92989095,
#        0.81542658, 0.92820739, 0.88074423, 0.64858157, 0.73342039,
#        0.68351121, 0.81411151, 0.86665687, 0.52307279, 0.68761127,
#        0.65918758, 0.7778779 , 0.83635922, 0.91519711, 0.66461006,
#        0.57748551, 0.72895031, 0.71043422, 0.89825604, 0.66436642,
#        0.94457159, 0.63326837, 0.79279315, 0.78322226, 0.71821524,
#        0.6544174 , 0.45071761, 0.65586932, 0.90375958, 0.75460154,
#        0.83837778, 0.68125867, 0.88015841, 0.65344351, 0.97287345,
#        0.71691654, 0.73994485, 0.82701864, 0.63811343, 0.66534207,
#        0.77772465, 0.56701255, 0.80310951, 0.73000019, 0.70716087,
#        0.88804623, 0.48158167, 0.52828226, 0.7966439 , 0.79067431,
#        0.91906691, 0.73374666, 0.87901756, 0.71685621, 0.53742315,
#        0.77533845, 0.85988088, 0.75115036, 0.65850502, 0.80420112,
# ...

# %%
y_test
# Out:
# array([0.67, 0.64, 0.8 , 0.81, 0.86, 0.58, 0.73, 0.56, 0.54, 0.94, 0.87,
#        0.95, 0.93, 0.67, 0.73, 0.64, 0.89, 0.9 , 0.44, 0.71, 0.57, 0.7 ,
#        0.82, 0.94, 0.65, 0.34, 0.74, 0.72, 0.93, 0.66, 0.96, 0.65, 0.78,
#        0.78, 0.75, 0.5 , 0.36, 0.62, 0.91, 0.78, 0.83, 0.69, 0.89, 0.54,
#        0.96, 0.76, 0.76, 0.8 , 0.66, 0.66, 0.55, 0.61, 0.82, 0.63, 0.76,
#        0.92, 0.49, 0.45, 0.77, 0.85, 0.91, 0.57, 0.91, 0.72, 0.59, 0.76,
#        0.87, 0.76, 0.72, 0.78, 0.84, 0.42, 0.74, 0.53, 0.84, 0.42, 0.49,
#        0.71, 0.71, 0.67, 0.44, 0.95, 0.71, 0.62, 0.64, 0.47, 0.73, 0.96,
#        0.71, 0.78, 0.52, 0.73, 0.8 , 0.81, 0.53, 0.62, 0.7 , 0.79, 0.87,
#        0.89, 0.92, 0.57, 0.73, 0.44, 0.74, 0.84, 0.84, 0.64, 0.9 , 0.74,
#        0.71, 0.47, 0.9 , 0.63, 0.75, 0.38, 0.72, 0.8 , 0.84, 0.82])

# %%
from sklearn import metrics
metrics.r2_score(y_test,y_pred)*100 #Accuracy
# Out:
# 81.03743116598136

# %%
metrics.mean_squared_error(y_test,y_pred)
# Out:
# 0.0043275097253291156
